# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt
t = np.array(range(1850,2020))
y0 = [0,300]
def rhs(y, t,kappa,kdeep,gamma_l,gamma_o,c_amp,alpha,beta_l,beta_o,lamb): 
    emis_t = lambda x:x
    T_a,C = y
    dT_a = 1/kappa*(6.3*np.log(C/300)-lamb*T_a-kdeep*T_a)
    dT_Cdt = [1/kappa*(6.3*np.log(C/300)-lamb*T_a)-kdeep*T_a,(emis_t(t)-(gamma_l+gamma_o)*dT_a*(1+T_a*c_amp))/(1+alpha*(beta_l))-beta_o*(alpha*C)]
    return np.array(dT_Cdt)

# %%
plt.plot(range(1850,2020),range(1850,2020))

# %%
mat=1.8e20
alpha=1e6/mat/12*1e15

# %%
t = np.array(range(1850,2020))  # the points of evaluation of solution
#r = ode(rhs).set_integrator("dopri5")  # choice of method
y = odeint(rhs,y0,t,args = (9.3,21,-0.13,0.2,1,alpha,1.9,1.6,0.9))

# %%
plt.plot(t, y[:, 0], 'b', label='theta(t)')
plt.xlabel('time')
plt.ylabel('Temperature')
# Out:
# Text(0, 0.5, 'Temperature')

# %%
plt.plot(t, y[:, 1], 'b', label='theta(t)')
plt.xlabel('time')
plt.ylabel('Carbon')
# Out:
# Text(0, 0.5, 'Carbon')
